# %%
#| hide
# %load_ext autoreload
# %autoreload 2

# %%
#| default_exp simulations

# %% [markdown]
# # DiffPALM – Example usage on prokaryotic datasets
#
# > API details.

# %%
import numpy as np
import sys
sys.path.append("../diffpalm/")
from msa_pairformer_core import DiffPALM
from msa_parsing import read_msa
from datasets import generate_dataset, dataset_tokenizer

from pathlib import Path
from datetime import datetime
import pickle
import torch


def save_parameters(parameters_all, filepath):
    """Saves the parameters dictionary"""
    for name, parameters in parameters_all.items():
        with open(filepath / f"{name}.pkl", "wb") as f:
            pickle.dump(parameters, f)
        with open(filepath / f"{name}.csv", "w") as f:
            for key in parameters.keys():
                f.write("%s, %s\n" % (key, parameters[key]))

# %%
# RESULTS_DIR = Path(input(prompt="Insert path to directory where results will be stored (default: 'Results'): ") or "Results")
# RESULTS_DIR.mkdir(exist_ok=True)

# DEVICE = input(prompt="Choose PyTorch device (default: 'cuda'): ") or "cuda"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'cpu'}")
# Out:
# Using device: NVIDIA GH200 480GB

# %% [markdown]
# Load one of the two prokaryotic datasets used in our paper: HK-RR and MALG-MALK.
#
# `get_species_name` extracts species names from the FASTA header.

# %%
# PROKARYOTIC DATASETS

msa_data = [read_msa("data/HK-RR/HK_in_Concat_nnn.fasta", -1),
            read_msa("data/HK-RR/RR_in_Concat_nnn.fasta", -1)]
get_species_name = (lambda strn: strn.split("|")[1])

# msa_data = [read_msa("data/MALG-MALK/MALG_cov75_hmmsearch_extr5000_withLast_b.fasta", -1),
#             read_msa("data/MALG-MALK/MALK_cov75_hmmsearch_extr5000_withLast_b.fasta", -1)]
# get_species_name = (lambda strn: strn.split("_")[-1])

# %%
len(np.unique([msa_data[0][i][0].split('|')[1] for i in range(len(msa_data[0]))]))
# Out:
# 2310

# %%
parameters_dataset = {
    "N": 1024,  # Average number of sequences in the input
    "pos": 0,  # Size of the context pairs to use as positive example 
    "max_size": 100,  # Max size of species MSAs (if same as N there is no limit on size)
    "NUMPY_SEED": 10,
    "NUMPY_SEED_OTHER": 11,
}

# %%
dataset, species_sizes = generate_dataset(
    parameters_dataset, msa_data, get_species_name=get_species_name
)
tokenized_dataset = dataset_tokenizer(dataset, device=device)

left_msa, right_msa = tokenized_dataset["msa"]["left"], tokenized_dataset["msa"]["right"]
positive_examples = tokenized_dataset["positive_examples"]
# Out:
# Generated initial MSA
# 	Species selected, total number of species selected:
# ['Actinoplanes_friuliensis_DSM_7358' 'Advenella_kashmirensis_WT001'
#  'Alcanivorax_dieselolei_B5' 'Alteromonas_macleodii_str._Black_Sea_11'
#  'Ammonifex_degensii_KC4' 'Anaerobaculum_mobile_DSM_13181'
#  'Arthrobacter_phenanthrenivorans_Sphe3' 'Azotobacter_vinelandii_DJ'
#  'Bacillus_thuringiensis_serovar_finitimus_YBT-020'
#  'Bacillus_thuringiensis_serovar_konkukian_str._97-27'
#  'Bacillus_thuringiensis_serovar_kurstaki_str._HD73'
#  'Bartonella_bacilliformis_KC583' 'Bartonella_henselae_str._Houston-1'
#  'Bibersteinia_trehalosi_USDA-ARS-USMARC-192'
#  'Bordetella_petrii_DSM_12804' 'Brachybacterium_faecium_DSM_4810'
#  'Brachyspira_intermedia_PWS/A' 'Brucella_ceti_TE10759-12'
#  'Burkholderia_sp._RPE64' 'Caldicellulosiruptor_lactoaceticus_6A'
#  'Campylobacter_jejuni_4031' 'Candidatus_Desulforudis_audaxviator_MP104C'
#  'Candidatus_Koribacter_versatilis_Ellin345'
#  'Chthonomonas_calidirosea_T49' 'Coprococcus_sp._ART55/1'
#  'Corynebacterium_diphtheriae_HC02' 'Corynebacterium_variabile_DSM_44702'
#  'Desulfomicrobium_baculatum_DSM_4028'
#  'Desulfotomaculum_acetoxidans_DSM_771'
#  'Desulfotomaculum_gibsoniae_DSM_7213' 'Desulfovibrio_vulgaris_RCH1'
#  'Edwardsiella_tarda_EIB202'
#  'Enterobacter_cloacae_subsp._cloacae_NCTC_9394' 'Escherichia_coli_IAI39'
#  'Escherichia_coli_O103:H2_str._12009'
#  'Escherichia_coli_O157:H7_str._Sakai' 'Escherichia_coli_O7:K1_str._CE10'
#  'Escherichia_fergusonii_ATCC_35469'
#  'Fibrobacter_succinogenes_subsp._succinogenes_S85'
#  'Geobacillus_sp._WCH70' 'Geobacillus_thermodenitrificans_NG80-2'
#  'Geodermatophilus_obscurus_DSM_43160' 'Haemophilus_influenzae_86-028NP'
#  'Halalkalicoccus_jeotgali_B3' 'Halanaerobium_hydrogeniformans'
#  'Helicobacter_pylori_F57' 'Klebsiella_pneumoniae_KCTC_2242'
#  'Kyrpidia_tusciae_DSM_2912' 'Lactobacillus_acidophilus_30SC'
#  'Lactobacillus_delbrueckii_subsp._bulgaricus_ATCC_BAA-365'
#  'Lactobacillus_plantarum_JDM1' 'Lactococcus_lactis_subsp._cremoris_SK11'
#  'Legionella_pneumophila_str._Corby' 'Leuconostoc_sp._C2'
#  'Listeria_monocytogenes_07PF0776' 'Mannheimia_haemolytica_M42548'
#  'Marinobacter_hydrocarbonoclasticus_ATCC_49840'
#  'Meiothermus_silvanus_DSM_9946'
#  'Methylobacterium_extorquens_DM4_(Methylobacterium'
#  'Mycobacterium_neoaurum_VKM_Ac-1815D'
#  'Mycobacterium_tuberculosis_RGTB327' 'Paenibacillus_mucilaginosus_K02'
#  'Pandoraea_pnomenusa_3kgm' 'Propionibacterium_acnes_266'
#  'Pseudomonas_putida_KT2440' 'Pseudomonas_sp._VLB120'
#  'Rhizobium_etli_CIAT_652' 'Rhodobacter_sphaeroides_ATCC_17029'
#  'Ruminococcus_champanellensis_18P13'
#  'Salmonella_enterica_subsp._enterica_serovar_Bovismorbificans_str.'
#  'Saprospira_grandis_str._Lewin' 'Sphaerobacter_thermophilus_DSM_20745'
#  'Sphaerochaeta_globus_str._Buddy'
#  'Staphylococcus_aureus_subsp._aureus_71193'
#  'Staphylococcus_aureus_subsp._aureus_Mu3'
#  'Staphylococcus_aureus_subsp._aureus_str._JKD6008'
#  'Streptococcus_pneumoniae_SPNA45' 'Streptococcus_pneumoniae_TCH8431/19A'
#  'Streptococcus_pseudopneumoniae_IS7493'
#  'Streptococcus_pyogenes_MGAS10394'
#  'Streptomyces_griseus_subsp._griseus_NBRC_13350'
#  'Streptomyces_hygroscopicus_subsp._jinggangensis_5008'
#  'Streptomyces_sp._PAMC26508' 'Sulfobacillus_acidophilus_TPY'
#  'Synechococcus_elongatus_PCC_7942' 'Taylorella_asinigenitalis_14/45'
#  'Thermaerobacter_marianensis_DSM_12885'
#  'Thermobaculum_terrenum_ATCC_BAA-798'
#  'Thermodesulfobium_narugense_DSM_14796'
#  'Thermosediminibacter_oceani_DSM_16646'
#  'Thioalkalivibrio_nitratireducens_DSM_14787' 'Vibrio_cholerae_IEC224'
#  'Vibrio_splendidus_LGP32' 'Vibrio_vulnificus_MO6-24/O'
#  'Yersinia_pestis_Z176003' 'Yersinia_pseudotuberculosis_IP_32953'
#  'uncultured_Sulfuricurvum_sp._RIFRC-1']
# [  56   62   79   94  105  115  135  149  222  223  224  240  243  254
#   296  311  312  331  377  389  406  429  430  554  614  628  668  737
#   743  745  759  777  789  835  842  850  855  875  896  934  938  950
#   971  985  986 1030 1100 1110 1113 1132 1149 1174 1187 1216 1221 1262
#  1273 1282 1317 1377 1401 1484 1494 1563 1620 1628 1667 1678 1764 1781
#  1819 1887 1888 1916 1932 1947 2030 2032 2036 2041 2089 2090 2093 2098
#  2110 2130 2144 2160 2166 2170 2192 2224 2242 2244 2285 2289 2309] , 97
# 	Pairs per species, total number of pairs:
# [39  7 17 17  6  2  7 18 25 28 23  5  5  3 18  6  2  6 19  6  4  2 23  4
#  12  6  4 20 15 22 16 15  8 14 14 13 14 14  3  6 12  7  2  2  5  2 17  7
#   6  6  6  5  6  4  8  2 17 10 18 10  5 26 20  4 30 31 15  7  6 15  5 10
#   4  8  9  8  6  6  6  6 23 19 18  5  2  6  6  9  3  7 13 15 19 19 14 13
#  11] , 1069

# %% [markdown]
# ## Train single block

# %%
EPOCHS = 100
TORCH_SEED = 100

parameters_init = {
    "device": DEVICE,
    "p_mask": 0.7,
    "random_seed": TORCH_SEED
}

parameters_train = {
    "std_init": 0.,
    "scheduler_name": "ReduceLROnPlateau",
    "scheduler_kwargs": {"mode": "min", "factor": 0.8, "patience": 20},
    "optimizer_name": "Adadelta",
    "optimizer_kwargs": {"lr": 9, "weight_decay": 1e-1},
    "tau": 1.,
    "n_sink_iter": 10,
    "batch_size": 1,
    "epochs": EPOCHS,
    "noise": True,
    "noise_factor": 0.1,  # If noise_std is False, this is just the std of the noise
    "noise_scheduler": True,
    "noise_std": True,
    "use_rand_perm": True,
}

parameters_target_loss = {
    "batch_size": 200
}

parameters_all = {
    "init": parameters_init,
    "target_loss": parameters_target_loss,
    "train": parameters_train,
    "dataset": parameters_dataset
}

# %%
dpalm = DiffPALM(species_sizes, **parameters_init)

# %%
date = datetime.now().strftime("%Y_%m_%d-%H:%M:%S")
output_dir = RESULTS_DIR / date
output_dir.mkdir()

save_parameters(parameters_all, output_dir)

# %% [markdown]
# When `save_all_figs=True`, a figure is saved and shown after each gradient step, illustrating the current state of the optimization. This slows the overall optimization down and may create memory leakage issues. Set `save_all_figs=False` to only have the figure saved and shown after the last gradient step.

# %% [markdown]
# The plotting function is able to show the number of correctly predicted pairs because the ground truth pairs are known. The model assumes that the input pairs are already correctly matched (i.e. the correct matching matrix is a diagonal matrix) because in the HK-RR and MALG-MALK datasets the sequences are are already ordered with the correct matches in the same position of the MSA.

# %%
tar_loss = dpalm.target_loss(
    left_msa,
    right_msa,
    positive_examples=positive_examples,
    **parameters_target_loss
)

(losses,
 list_scheduler,
 shuffled_indexes,
 mat_perm,
 mat_gs,
 list_log_alpha) = dpalm.train(
    left_msa,
    right_msa,
    positive_examples=positive_examples,
    tar_loss=np.mean(tar_loss),
    output_dir=output_dir,
    save_all_figs=True,
    **parameters_train,
)

results = {
    "trainng_results": (losses, list_scheduler, shuffled_indexes, [mat_perm, mat_gs], list_log_alpha),
    "target_loss": tar_loss,
    "species_sizes": species_sizes
}
