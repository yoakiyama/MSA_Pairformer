# %%
# %load_ext autoreload
# %autoreload 2
import os
import pickle
import numpy as np
from tqdm import tqdm

import torch
from esm.models.esmc import ESMC
from esm.tokenization import EsmSequenceTokenizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load model
head_out_dir = "/home/yo_aki/AF_inv_covariance/notebook_outs/09h_fit_esmc_contact_heads/esmc_6b/"
model = ESMC.from_pretrained("esmc_6b", use_flash_attn=False, init_contact_head=True, contact_head_weights_path=os.path.join(head_out_dir, "esmc_6b_contact_head.pt")).to(device)
model.eval()
print("Successfully loaded model")
# Print number of parameters
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {total_params:,}")

# Load tokenizer
tokenizer = EsmSequenceTokenizer()
# Out:
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# Successfully loaded model
# Number of parameters: 6,352,008,385

# %%
# Alignments directory
target_data_file = "/home/yo_aki/orcd/pool/MSA_Pairformer_data/Figure2_heterooligomer_contact_prediction/target_data.pkl"
with open(target_data_file, "rb") as oFile:
    target_data_d = pickle.load(oFile)

# %%
predicted_contacts_d = {}
for target in tqdm(target_data_d.keys()):
    msa_file = target_data_d[target]['msa_file'].replace("../../data/", "../../../orcd/pool/MSA_Pairformer_data/")
    # Load alignment
    with open(msa_file, "r") as oFile:
        query_seq = oFile.readlines()[1].strip()
    len_seq = len(query_seq)
    # Predict contacts
    tokens = tokenizer.encode(query_seq, return_tensors="pt").to(device)
    with torch.no_grad():
        # Compute attention heads
        output = model(sequence_tokens=tokens, output_attentions=True, return_contacts=True)
        pred_contacts_a = output.contacts[0].float().cpu().numpy()
    predicted_contacts_d[target] = pred_contacts_a
with open("results/esmc_6b/esmc_ppi_predicted_contacts.pkl", "wb") as oFile:
    pickle.dump(predicted_contacts_d, oFile)
# Out:
# 100%|██████████| 30/30 [01:16<00:00,  2.56s/it]

# %%
for target in predicted_contacts_d:
    np.savetxt(f"results/esmc_6b/{target}.esmc_6b.txt", predicted_contacts_d[target])
